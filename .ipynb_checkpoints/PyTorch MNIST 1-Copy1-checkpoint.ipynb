# %%
import torch
import numpy as np

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt

training_data = datasets.MNIST(root=".", train=True, download=True, transform=ToTensor())

test_data = datasets.MNIST(root=".", train=False, download=True, transform=ToTensor())

# %%
from torch.utils.data import DataLoader

loaded_train = DataLoader(training_data, batch_size=64, shuffle=True)
loaded_test = DataLoader(test_data, batch_size=64, shuffle=True)

# %%
from torch import nn

class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
from torch import nn
x = 64
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, x),
            nn.ReLU(),
            nn.Linear(x, x),
            nn.ReLU(),
            nn.Linear(x, x),
            nn.ReLU(),
            nn.Linear(x, x),
            nn.ReLU(),
            nn.Linear(x, x),
            nn.ReLU(),
            nn.Linear(x, x),
            nn.ReLU(),
            nn.Linear(x, x),
            nn.ReLU(),
            nn.Linear(x, x),
            nn.ReLU(),
            nn.Linear(x, x),
            nn.ReLU(),
            nn.Linear(x, 10),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
model = NeuralNetwork()
print(model)
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=64, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=64, out_features=64, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=64, out_features=64, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=64, out_features=64, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=64, out_features=64, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=64, out_features=64, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=64, out_features=64, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=64, out_features=64, bias=True)
#     (21): ReLU()
#     (22): Linear(in_features=64, out_features=64, bias=True)
#     (23): ReLU()
#     (24): Linear(in_features=64, out_features=64, bias=True)
#     (25): ReLU()
#     (26): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
loss_function = nn.CrossEntropyLoss()
optimizer = optimizer.Adam(model.parameters(), lr=learning_rate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 2
#       1 loss_function = nn.CrossEntropyLoss()
# ----> 2 optimizer = optimizer.Adam(model.parameters(), lr=learning_rate)
#
# AttributeError: 'SGD' object has no attribute 'Adam'

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        pred = model(X)
        loss = loss_fn(pred, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 30
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(loaded_train, model, loss_function, optimizer)
    test(loaded_test, model, loss_function)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.300930
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.300964
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301150
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.300996
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.300934
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.300958
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.300978
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301006
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301007
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301073
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301007
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301013
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301026
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.300937
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301100
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301009
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.300885
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301056
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.300953
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301097
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301006
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301004
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301171
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301032
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301068
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301096
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301003
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301182
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.300972
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301054
#
# Done!

# %%
torch.save(model, "model1.pth")

# %%
model = torch.load("model1.pth", weights_only=True)
